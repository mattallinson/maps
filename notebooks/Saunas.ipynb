# %%
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
import geoplot as gplt
import geoplot.crs as gcrs

# %% [raw]
# import requests
#
# overpass_url = "http://overpass-api.de/api/interpreter"
#
# overpass_query = """
# [out:json];
# area["ISO3166-1"="FI"][admin_level=2];
# (node["leisure"="sauna"](area);
#  way["leisure"="sauna"](area);
#  rel["leisure"="sauna"](area);
# );
# out center;
# """
#
# response = requests.get(overpass_url,
#                         params={'data': overpass_query})
# data = response.json()
# df = pd.DataFrame(data['elements'])
# df.to_pickle('./data/saunas.pkl')

# %%
# run the above cell to get the data from overpass, which we then import below and turn into a geojson file
df = pd.read_pickle('./data/saunas.pkl')
saunas = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon,df.lat))

# %%
saunas.head()
# Out:
#    type         id        lat        lon  \
# 0  node  282605605  67.065282  27.226692
# 1  node  308296177  62.989946  29.918683
# 2  node  386025854  61.475913  23.894145
# 3  node  440322409  60.806357  24.609396
# 4  node  466976088  60.474127  22.004490
#
#                                                 tags  \
# 0  {'description': 'Pyhän Oravan rantasauna, joss...
# 1  {'leisure': 'sauna', 'name': 'Kiviniemen sauna...
# 2                               {'leisure': 'sauna'}
# 3  {'leisure': 'sauna', 'note': 'miesten sauna ja...
# 4                               {'leisure': 'sauna'}
#
#                     geometry
# 0  POINT (27.22669 67.06528)
# 1  POINT (29.91868 62.98995)
# 2  POINT (23.89414 61.47591)
# 3  POINT (24.60940 60.80636)
# 4  POINT (22.00449 60.47413)

# %%
world = gpd.read_file('./maps/ne_10m_admin_1_states_provinces_lakes.shp')
country = world.query('admin in ["Finland", "Aland"]')

# %%
background_color = "#fffaf0"

ax = gplt.polyplot(country, 
                      figsize=(24, 24), 
                      projection=gcrs.Mercator(),
                      facecolor="#E4F0FB"
                     )
j = gplt.pointplot(saunas, ax=ax, color='red',marker="o", alpha=0.2, s=10)
k = gplt.pointplot(saunas, ax=ax, color='red',marker="p")
ax.patch.set_facecolor(background_color)
plt.savefig('./output/saunas_in_finland.png', facecolor=background_color)
plt.show()
